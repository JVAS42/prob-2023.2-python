# %% [markdown]
# # <font color=green size=8>Estatística e Probabilidade II</font>
# ***
# ## Atividade com análise de regressão

# %% [markdown]
# # <font color=green>DATASET DO PROJETO</font>
#
# ***
# ### **Fonte:** https://www.kaggle.com/dongeorge/beer-consumption-sao-paulo
#
# Os dados (amostra) foram coletados em São Paulo - Brasil, em uma área universitária, onde existem algumas festas com grupos de alunos de 18 a 28 anos de idade (média).
#
# ### **Dados**
# - **X** - Temperatura Média (°C)
# - **Y** - Consumo de Cerveja (Litros)
#
# ### **Resumo:** https://www.youtube.com/watch?v=9BjLLEpxKfI&ab_channel=CanaldoPorQu%C3%AA%3F

# %%
#############################
# IMPORTANDO AS BIBLIOTECAS #
#############################
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import probplot
import matplotlib.pyplot as plt

# %%
########################
# IMPORTANDO O DATASET #
########################
dataset = pd.read_csv('dados_projeto.csv', sep=';')

# %% [markdown]
# ### Visualização prévia do Dataset e seu conteúdo
# ***

# %%
dataset.shape #(Quantidace de Linha, Quantidade de Coluna)
# Out:
# (365, 2)

# %%
dataset.head(30) #Mostrar os dados(Quantidade de tuplas mostradas)
# Out:
#         Y      X
# 0   25461  27.30
# 1   28972  27.02
# 2   30814  24.82
# 3   29799  23.98
# 4   28900  23.82
# 5   28218  23.78
# 6   29732  24.00
# 7   28397  24.90
# 8   24886  28.20
# 9   37937  26.76
# 10  36254  27.62
# 11  25743  25.96
# 12  26990  25.52
# 13  31825  25.96
# 14  25724  25.86
# 15  29938  26.50
# 16  37690  28.86
# 17  30524  28.26
# 18  29265  28.22
# 19  35127  27.68
# 20  29130  25.32
# 21  25795  21.74
# 22  21784  21.04
# 23  28348  23.12
# 24  31088  24.40
# 25  21520  22.40
# 26  29972  23.60
# 27  22603  25.68
# 28  22696  25.00
# 29  26845  22.80

# %% [markdown]
# # <font color=green>ANÁLISE GRÁFICA</font>
#
# ***
# ### Anova com Box plot

# %%
ax = sns.boxplot(data=dataset, x='Y', orient='h', width=0.5)
ax.figure.set_size_inches(12, 6)
ax.set_title('Box plot', fontsize=20)
ax.set_xlabel('Consumo de cerveja (litros)', fontsize=16)
ax
# Out:
# <Axes: title={'center': 'Box plot'}, xlabel='Consumo de cerveja (litros)'>

# %%
ax = sns.boxplot(data=dataset, x = 'X', orient='h', width=0.5)
ax.figure.set_size_inches(12, 6)
ax.set_title('Box plot', fontsize=20)
ax.set_xlabel('Temperatura média', fontsize=16)
ax
# Out:
# <Axes: title={'center': 'Box plot'}, xlabel='Temperatura média'>

# %% [markdown]
# ### Análise de regressão $X$ Temperatura da cerveja  e $Y$ Consumo de cerveja em Litros
# ### <font color='green'>Utilizando gráfico de dispersão & Correlação com reta </font>

# %%
ax = sns.lmplot(x="X", y="Y", data=dataset)
ax.fig.set_size_inches(12, 6)
ax.fig.suptitle('Reta de Regressão - Temperatura X Consumo', fontsize=16, y=1.02)
ax.set_xlabels("Temperatura média", fontsize=14)
ax.set_ylabels("Consumo de cerveja (Litros)", fontsize=14)
ax

# %% [markdown]
# ### Resultado da regressão
# ***

# %%
dataset.corr()
# Out:
#           Y         X
# Y  1.000000  0.574615
# X  0.574615  1.000000

# %%
Y = dataset.Y
X = sm.add_constant(dataset.X)

# %%
resultado_regressao = sm.OLS(Y, X).fit()

# %%
print(resultado_regressao.summary()) #Resultado da regressão em sumário
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.330
# Model:                            OLS   Adj. R-squared:                  0.328
# Method:                 Least Squares   F-statistic:                     178.9
# Date:                Fri, 24 Nov 2023   Prob (F-statistic):           1.87e-33
# Time:                        15:36:19   Log-Likelihood:                -3506.3
# No. Observations:                 365   AIC:                             7017.
# Df Residuals:                     363   BIC:                             7024.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8528.9073   1275.363      6.687      0.000    6020.880     1.1e+04
# ...
